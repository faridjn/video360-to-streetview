# %%
# Author: Farid Javadnejad
# Date: 2025-11-11
# Last Update: 2025-12-12
# 
# DESCRIPTION:
# - Script: Converts 360° video frames into Google Street View-style panoramas
# - INPUT_DIR: Source 360° video file (.mp4)
# - OUTPUT_DIR: Extracted and processed panoramic frames
# - Process:
#     - Splits video into frames
#     - Projects equirectangular frames into cube faces
#     - Reconstructs Street View-like perspective images
#     - Uses OpenCV and image transformation techniques for projection
# 
# DISCLAIMER:
# This script was developed with the assistance of AI tools for debugging, reviewing, and testing.

# %%
# --- Instalation ---
# !pip install gpxpy
# !pip install pyproj
# !pip install av
# !pip install python-xmp-toolkit
# !pip install pillow
# !pip install piexif

# %%
import os, csv, math
from pathlib import Path
from datetime import datetime, timezone
from fractions import Fraction
from urllib.parse import quote
import numpy as np
import gpxpy
from pyproj import Transformer
import av

# %%
# ---------- CONFIG ----------
ROOT = Path(r'C:\Farid\GitHub\video360-to-streetview\data\input')
FILE_NAME = "VID_20251111_130157_00_032.mp4"
OUT_DIR = ROOT / "output_3"

VIDEO   = ROOT / FILE_NAME
GPX     = VIDEO.with_suffix(".gpx")   # assumes .gpx shares the same stem & folder as the .mp4

SPACING_M       = 10.0      # image every N meters
CRS_EPSG        = 4326     # EPSG defintion
TIME_OFFSET_S   = 0.0      # adjust if camera clock != GPS time
USE_QUATERNION  = False    # True => output qw,qx,qy,qz; else heading
WRITE_EXIF      = True     # python-only EXIF/XMP (no exiftool needed)
EPOCH_IS_MS     = False    # set True if GPX epoch values are milliseconds
YAW_SIGN        = 1.0      # set -1.0 if viewer faces opposite way

# Ensure output directory exists
OUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Video path: {VIDEO}")
print(f"GPX path:   {GPX}")
print(f"Output dir: {OUT_DIR}")

# %%
# ---------- Geo helpers ----------
def haversine_m(lat1, lon1, lat2, lon2):
    R = 6378137.0
    dlat = math.radians(lat2 - lat1)
    dlon = math.radians(lon2 - lon1)
    a = math.sin(dlat/2)**2 + math.cos(math.radians(lat1))*math.cos(math.radians(lat2))*math.sin(dlon/2)**2
    return 2 * R * math.asin(math.sqrt(a))

def bearing_deg(lat1, lon1, lat2, lon2):
    y = math.sin(math.radians(lon2 - lon1)) * math.cos(math.radians(lat2))
    x = (math.cos(math.radians(lat1)) * math.sin(math.radians(lat2)) -
         math.sin(math.radians(lat1)) * math.cos(math.radians(lat2)) * math.cos(math.radians(lon2 - lon1)))
    brng = math.degrees(math.atan2(y, x))
    return (brng + 360) % 360

def ypr_to_quaternion(yaw_deg, pitch_deg=0.0, roll_deg=0.0):
    rz, ry, rx = map(math.radians, (yaw_deg, pitch_deg, roll_deg))
    cz, sz = math.cos(rz/2), math.sin(rz/2)
    cy, sy = math.cos(ry/2), math.sin(ry/2)
    cx, sx = math.cos(rx/2), math.sin(rx/2)
    qw = cx*cy*cz + sx*sy*sz
    qx = sx*cy*cz - cx*sy*sz
    qy = cx*sy*cz + sx*cy*sz
    qz = cx*cy*sz - sx*sy*cz
    return (qw, qx, qy, qz)

# ---------- 1) READ GPX & build distance/time series ----------
with open(GPX, 'r', encoding='utf-8') as f:
    gpx = gpxpy.parse(f)

points = []
for track in gpx.tracks:
    for seg in track.segments:
        for p in seg.points:
            if p.time is None:
                continue
            points.append((p.time.replace(tzinfo=timezone.utc), p.latitude, p.longitude, p.elevation or 0.0))
if len(points) < 2:
    raise RuntimeError("Not enough GPX points with time.")

# Sort by time, compute cumulative distance and segment bearings
points.sort(key=lambda r: r[0])
times = [t.timestamp() for (t, _, _, _) in points]  # epoch seconds UTC
lats  = [lat for (_, lat, _, _) in points]
lons  = [lon for (_, _, lon, _) in points]
eles  = [ele for (_, _, _, ele) in points]

total_dist = [0.0]
brngs = [0.0]
for i in range(1, len(points)):
    _, lat1, lon1, _ = points[i-1]
    _, lat2, lon2, _ = points[i]
    d = haversine_m(lat1, lon1, lat2, lon2)
    total_dist.append(total_dist[-1] + d)
    brngs.append(bearing_deg(lat1, lon1, lat2, lon2))

# ---------- 2) Choose target distances ----------
total = total_dist[-1]
targets = np.arange(0.0, total, SPACING_M)
if total - targets[-1] > SPACING_M * 0.5:
    targets = np.append(targets, total)

# ---------- 3) Interpolate timestamp/lat/lon/ele/heading at each target ----------
td = np.array(total_dist, dtype=float)
t_vals   = np.interp(targets, td, np.array(times, dtype=float)) + TIME_OFFSET_S
lat_vals = np.interp(targets, td, np.array(lats,  dtype=float))
lon_vals = np.interp(targets, td, np.array(lons,  dtype=float))
ele_vals = np.interp(targets, td, np.array(eles,  dtype=float))
hdg_vals = np.interp(targets, td, np.array(brngs, dtype=float))  # degrees CW from north

samples = list(zip(targets, t_vals, lat_vals, lon_vals, ele_vals, hdg_vals))

# ---------- 4) Transform to project CRS ----------
transformer = Transformer.from_crs("EPSG:4326", f"EPSG:{CRS_EPSG}", always_xy=True)
xyz_samples = []
for d, t, lat, lon, ele, hdg in samples:
    x, y = transformer.transform(lon, lat)
    xyz_samples.append((d, t, x, y, ele, lat, lon, hdg))

# ---------- 5) Extract frames with PyAV ----------
warnings = []
jpg_files = []

def _to_rel_sec(t_epoch, t0):
    t = float(t_epoch)
    if EPOCH_IS_MS:
        t *= 0.001
    return t - float(t0)

target_rel_secs = [_to_rel_sec(t_epoch, times[0]) for (_, t_epoch, *_rest) in xyz_samples]

container = av.open(str(VIDEO))
try:
    vstream = next((s for s in container.streams if s.type == 'video'), None)
    if vstream is None:
        warnings.append(f"No video stream found in: {VIDEO}")
    else:
        tb = vstream.time_base
        start_pts = vstream.start_time or 0
        start_sec = float(start_pts * tb)
        if vstream.duration and vstream.duration > 0:
            dur_sec = float(vstream.duration * tb)
        elif container.duration and container.duration > 0:
            dur_sec = float(container.duration * av.time_base)
        else:
            dur_sec = None

        def clamp_rel(t_rel):
            t_rel = float(t_rel)
            return max(0.0, t_rel) if dur_sec is None else min(max(0.0, t_rel), dur_sec)

        def _frame_seconds(frame):
            if frame.time is not None and math.isfinite(frame.time):
                abs_sec = float(frame.time)
            elif frame.pts is not None:
                abs_sec = float(frame.pts * vstream.time_base)
            else:
                return None, None
            return abs_sec, abs_sec - start_sec

        def save_frame_at_seconds(target_rel_sec, out_path, tol=0.050, backoff=0.5, accept_end_fallback=True):
            tgt = clamp_rel(target_rel_sec)
            reason = None
            if dur_sec is not None and target_rel_sec > dur_sec + 1e-6:
                reason = f"target {target_rel_sec:.3f}s exceeds duration {dur_sec:.3f}s; clamped to {tgt:.3f}s"

            seek_sec = max(start_sec, start_sec + tgt - backoff)
            seek_pts = int(round(seek_sec / vstream.time_base))
            try:
                container.seek(seek_pts, stream=vstream, any_frame=False, backward=True)
            except av.AVError as e:
                return False, f"seek failed at {seek_sec:.3f}s (pts={seek_pts}): {e}"

            last_frame = None
            last_rel   = None
            try:
                for frame in container.decode(vstream):
                    abs_sec, rel_sec = _frame_seconds(frame)
                    if rel_sec is None:
                        continue
                    last_frame, last_rel = frame, rel_sec
                    if (rel_sec + tol) >= tgt:
                        img = frame.to_image()
                        Path(out_path).parent.mkdir(parents=True, exist_ok=True)
                        img.save(out_path, "JPEG", quality=92, optimize=True)
                        return True, None
                    if (rel_sec - tgt) > 2.0:
                        break
            except av.AVError as e:
                return False, f"decode failed near {tgt:.3f}s: {e}"

            if accept_end_fallback and (last_frame is not None) and (dur_sec is not None):
                if tgt >= (dur_sec - max(tol, 0.050)):
                    img = last_frame.to_image()
                    Path(out_path).parent.mkdir(parents=True, exist_ok=True)
                    img.save(out_path, "JPEG", quality=92, optimize=True)
                    return True, None

            return False, (reason or f"no frame found close to {tgt:.3f}s (tolerance {tol:.3f}s)")

        for idx, target_rel in enumerate(target_rel_secs):
            out = OUT_DIR / f"pano_{idx:05d}.jpg"
            ok, reason = save_frame_at_seconds(float(target_rel), out, tol=0.050, backoff=0.5, accept_end_fallback=True)
            if not ok:
                ok2, reason2 = save_frame_at_seconds(float(target_rel), out, tol=0.150, backoff=0.75, accept_end_fallback=True)
                if ok2:
                    jpg_files.append(out)
                    if reason:
                        warnings.append(f"[idx {idx}] {reason} (recovered on second pass)")
                else:
                    warnings.append(f"[idx {idx}] skipped: {reason2 or reason}")
            else:
                jpg_files.append(out)
finally:
    try:
        container.close()
    except Exception:
        pass

for msg in warnings:
    print(f"WARN | {msg}")

# ---------- 6) Write EXIF GPS + GPano (python-only; no exiftool) ----------
try:
    import piexif
except ImportError as e:
    raise RuntimeError("piexif is required for Python-only EXIF writing. Install with: pip install piexif") from e

try:
    from libxmp import XMPFiles, XMPMeta
    HAVE_XMP = True
except Exception:
    HAVE_XMP = False
    print("Note: 'python-xmp-toolkit' not found; GPano XMP will be skipped. Install with: pip install python-xmp-toolkit")

try:
    from PIL import Image
    HAVE_PIL = True
except Exception:
    HAVE_PIL = False
    if HAVE_XMP:
        print("Note: Pillow not available; GPano sizing tags will be omitted. Install with: pip install pillow")

def _to_dms_rational(val: float):
    sign = 1 if val >= 0 else -1
    v = abs(val)
    deg = int(v)
    min_float = (v - deg) * 60
    minute = int(min_float)
    sec = (min_float - minute) * 60
    def rat(x):
        f = Fraction(x).limit_denominator(1_000_000)
        return (f.numerator, f.denominator)
    dms = (rat(deg), rat(minute), rat(sec))
    return sign, dms

def write_gps_exif_piexif(jpg_path: Path, lat: float, lon: float, alt_m: float, dt_original_str: str):
    try:
        exif_dict = piexif.load(str(jpg_path))
    except Exception:
        exif_dict = {"0th": {}, "Exif": {}, "GPS": {}, "1st": {}, "thumbnail": None}

    lat_sign, lat_dms = _to_dms_rational(lat)
    lon_sign, lon_dms = _to_dms_rational(lon)

    gps_ifd = exif_dict.get("GPS", {})
    gps_ifd[piexif.GPSIFD.GPSVersionID]  = (2, 0, 0, 0)
    gps_ifd[piexif.GPSIFD.GPSLatitudeRef]  = 'N' if lat_sign >= 0 else 'S'
    gps_ifd[piexif.GPSIFD.GPSLatitude]     = lat_dms
    gps_ifd[piexif.GPSIFD.GPSLongitudeRef] = 'E' if lon_sign >= 0 else 'W'
    gps_ifd[piexif.GPSIFD.GPSLongitude]    = lon_dms
    gps_ifd[piexif.GPSIFD.GPSAltitudeRef]  = 0 if alt_m >= 0 else 1
    gps_ifd[piexif.GPSIFD.GPSAltitude]     = (int(round(abs(alt_m) * 100)), 100)  # centimeters denominator

    exif_ifd = exif_dict.get("Exif", {})
    exif_ifd[piexif.ExifIFD.DateTimeOriginal] = dt_original_str

    exif_dict["GPS"]  = gps_ifd
    exif_dict["Exif"] = exif_ifd
    piexif.insert(piexif.dump(exif_dict), str(jpg_path))

def write_gpano_xmp(jpg_path: Path, heading_deg: float):
    if not HAVE_XMP:
        return
    ns = "http://ns.google.com/photos/1.0/panorama/"
    prefix = "GPano"
    width = height = None
    if HAVE_PIL:
        try:
            with Image.open(jpg_path) as im:
                width, height = im.size
        except Exception:
            pass

    xmpfile = XMPFiles(file_path=str(jpg_path), open_forupdate=True)
    try:
        xmp = xmpfile.get_xmp() or XMPMeta()
        if not xmp.does_namespace_exist(ns):
            XMPMeta.register_namespace(ns, prefix)

        xmp.set_property(ns, "ProjectionType", "equirectangular")
        xmp.set_property(ns, "UsePanoramaViewer", True)
        xmp.set_property(ns, "PoseHeadingDegrees", f"{float(heading_deg):.2f}")

        if width and height:
            xmp.set_property(ns, "CroppedAreaImageWidthPixels",  str(width))
            xmp.set_property(ns, "CroppedAreaImageHeightPixels", str(height))
            xmp.set_property(ns, "FullPanoWidthPixels",          str(width))
            xmp.set_property(ns, "FullPanoHeightPixels",         str(height))
            xmp.set_property(ns, "CroppedAreaLeftPixels",        "0")
            xmp.set_property(ns, "CroppedAreaTopPixels",         "0")

        xmpfile.put_xmp(xmp)
    finally:
        xmpfile.close_file()

if WRITE_EXIF:
    for idx, jf in enumerate(jpg_files):
        _, t_epoch, x, y, z, lat, lon, hdg = xyz_samples[idx]
        ts = datetime.fromtimestamp(t_epoch, tz=timezone.utc).strftime("%Y:%m:%d %H:%M:%S")
        write_gps_exif_piexif(jf, lat, lon, z, ts)
        write_gpano_xmp(jf, hdg)

# ---------- 7) Build CSV ----------
csv_path = OUT_DIR / "panos.csv"
with open(csv_path, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    if USE_QUATERNION:
        writer.writerow(["filename","x","y","z","qw","qx","qy","qz"])
        for idx, jf in enumerate(jpg_files):
            _, _, x, y, z, _, _, hdg = xyz_samples[idx]
            qw,qx,qy,qz = ypr_to_quaternion(yaw_deg=hdg)
            writer.writerow([jf.name, f"{x:.3f}", f"{y:.3f}", f"{z:.3f}", f"{qw:.8f}", f"{qx:.8f}", f"{qy:.8f}", f"{qz:.8f}"])
    else:
        writer.writerow(["filename","x","y","z","heading"])
        for idx, jf in enumerate(jpg_files):
            _, _, x, y, z, _, _, hdg = xyz_samples[idx]
            writer.writerow([jf.name, f"{x:.3f}", f"{y:.3f}", f"{z:.3f}", f"{hdg:.2f}"])

print(f"Done. Panos in: {OUT_DIR}")
print(f"CSV for Panos: {csv_path}")

# ---------- 8) Write KML (thumbnail + interactive viewer link) ----------
KML_PATH = OUT_DIR / "panos.kml"
thumb_width   = 300
USE_HTTP_LINKS = False  # set True if serving OUT_DIR via http://127.0.0.1:8000/

base_href = "http://127.0.0.1:8000/viewer.html?img=" if USE_HTTP_LINKS else "viewer.html?img="

with open(KML_PATH, "w", encoding="utf-8") as f:
    f.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    f.write('<kml xmlns="http://www.opengis.net/kml/2.2">\n')
    f.write('  <Document>\n')
    f.write('    <name>360 Panos</name>\n')

    for idx, jf in enumerate(jpg_files):
        _, _, x, y, z, lat, lon, hdg = xyz_samples[idx]
        photo_id = jf.name
        
# ---------- 8) Write KML (thumbnail only, no interactive link) ----------
KML_PATH = OUT_DIR / "panos.kml"
thumb_width = 300

with open(KML_PATH, "w", encoding="utf-8") as f:
    f.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    f.write('<kml xmlns="http://www.opengis.net/kml/2.2">\n')
    f.write('  <Document>\n')
    f.write('    <name>360 Panos</name>\n')

    for idx, jf in enumerate(jpg_files):
        _, _, x, y, z, lat, lon, hdg = xyz_samples[idx]
        photo_id = jf.name
        coords = f"{lon:.8f},{lat:.8f},{z:.2f}"

        thumb_src = photo_id  # local path or HTTP if serving externally

        # Description without interactive link
        desc = f"""<![CDATA[
                <p><b>{photo_id}</b></p>
                <p>Heading: {hdg:.2f}°</p>
                <p><img src="{thumb_src}" width="{thumb_width}"></p>
                ]]>"""

        f.write('    <Placemark>\n')
        f.write(f'      <name>{photo_id}</name>\n')
        f.write(f'      <description>{desc}</description>\n')
        f.write('      <Point>\n')
        f.write(f'        <coordinates>{coords}</coordinates>\n')
        f.write('      </Point>\n')
        f.write('    </Placemark>\n')

    f.write('  </Document>\n')
    f.write('</kml>\n')

print("KML written:", KML_PATH)
# Out:
# Video path: c:\Farid\GitHub\video360-to-streetview\data\input\VID_20251111_130157_00_032.mp4
# GPX path:   c:\Farid\GitHub\video360-to-streetview\data\input\VID_20251111_130157_00_032.gpx
# Output dir: c:\Farid\GitHub\video360-to-streetview\data\output_utm
